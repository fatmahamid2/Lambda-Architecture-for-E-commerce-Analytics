# %%
#import libararies
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.window import Window
from IPython.display import display, HTML
display(HTML("<style>pre { white-space: pre !important; }</style>"))
import os
import findspark
findspark.init("F:/programmes/spark-3.5.5-bin-hadoop3")
# Out:
# <style>pre { white-space: pre !important; }</style>

# %%
#pathes for used jars (for postgre , hadoob, clickhouse)
jdbc_driver_path = "F:/programmes/spark-3.5.5-bin-hadoop3/jars/*"

# %%
#Bulid spark session
spark = SparkSession.builder \
    .appName("productDim") \
    .config("spark.driver.extraClassPath", jdbc_driver_path) \
    .config("spark.executor.extraClassPath", jdbc_driver_path) \
    .getOrCreate()

print("✅ SparkSession created successfully!")
# Out:
# ✅ SparkSession created successfully!

# %%
# Set up connection to PostgreSQL database

properties = {
    "user": "postgres",
    "password": "123",
    "driver": "org.postgresql.Driver"
}

# %%
#Reding products table from postgre
products_df = spark.read \
    .format("jdbc") \
    .option("url", "jdbc:postgresql://localhost:5432/olist?ssl=false")\
    .option("dbtable", "public.products") \
    .option("user", "postgres") \
    .option("password", "123") \
    .option("driver", "org.postgresql.Driver") \
    .load()

# %%
#Reding products category translation from postgre
translations_df = spark.read \
    .format("jdbc") \
    .option("url", "jdbc:postgresql://localhost:5432/olist?ssl=false")\
    .option("dbtable", "public.product_category_translation") \
    .option("user", "postgres") \
    .option("password", "123") \
    .option("driver", "org.postgresql.Driver") \
    .load()

# %%
# Adding the English translation for `product_category_name`
products_english_df = products_df.join(
    translations_df,
    on="product_category_name",
    how="left"
).select(
    products_df["*"],  # all coulmns
    translations_df["product_category_name_english"] # translation column
)

# %%
products_english_df.show()
# Out:
# +--------------------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+--------------------+-----------------------------+
# |          product_id|product_category_name|product_name_length|product_description_length|product_photos_qty|product_weight_g|product_length_cm|product_height_cm|product_width_cm|        product_name|product_category_name_english|
# +--------------------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+--------------------+-----------------------------+
# |3aa071139cb16b67c...|                artes|                 44|                       276|                 1|            1000|               30|               18|              20|Essential Canvas ...|                          art|
# |cef67bcfe19066a93...|                bebes|                 27|                       261|                 1|             371|               26|                4|              26|Premium Babies St...|                         baby|
# |03b63c5fc16691530...|                bebes|                 49|                       728|                 4|            7150|               50|               19|              45|Deluxe Babies Pro...|                         baby|
# |8c92109888e8cdf9d...|           brinquedos|                 36|                      1156|                 1|             600|               17|               10|              12|Classic Toys Plus...|                         toys|
# |14aa47b7fe5c25522...|      cama_mesa_banho|                 54|                       630|                 1|            1100|               16|               10|              16|Deluxe Bed Table ...|               bed_bath_table|
# |f53103a77d9cf245e...|      cama_mesa_banho|                 52|                       206|                 1|             500|               16|               10|              16|Premium Bed Table...|               bed_bath_table|
# |eb31436580a610f20...| construcao_ferram...|                 59|                      1602|                 4|             200|               17|                7|              17|Premium Construct...|         construction_tool...|
# |732bd381ad09e530f...|           cool_stuff|                 56|                      1272|                 4|           18350|               70|               24|              44|Essential Cool St...|                   cool_stuff|
# |37cc742be07708b53...|     eletrodomesticos|                 57|                       163|                 1|             400|               27|               13|              17|Professional Hous...|              home_appliances|
# |96bd76ec8810374ed...|        esporte_lazer|                 46|                       250|                 1|             154|               18|                9|              15|PowerFlex Trainin...|               sports_leisure|
# |3bb7f144022e67327...|        esporte_lazer|                 22|                      3021|                 1|             800|               16|                2|              11|SportEx Sports Ba...|               sports_leisure|
# |a1b71017a84f92fd8...| informatica_acess...|                 59|                       636|                 1|             900|               40|               15|              20|Deluxe Informatic...|         computers_accesso...|
# |41d3672d4792049fa...| instrumentos_musi...|                 60|                       745|                 1|             200|               38|                5|              11|Deluxe Musical In...|          musical_instruments|
# |cf55509ea8edaaac1...| instrumentos_musi...|                 43|                      1827|                 3|             250|               17|                7|              17|Professional Musi...|          musical_instruments|
# |2548af3e6e77a690c...|     moveis_decoracao|                 56|                       184|                 2|             900|               40|                8|              40|Professional Furn...|              furniture_decor|
# |7bb6f29c2be577161...|     moveis_decoracao|                 51|                      2083|                 2|             600|               68|               11|              13|Deluxe Furniture ...|              furniture_decor|
# |a0736b92e52f6cead...|     moveis_decoracao|                 56|                       296|                 2|            1700|              100|                7|              15|Classic Furniture...|              furniture_decor|
# |1c1890ba1779090cd...|     moveis_decoracao|                 27|                       158|                 4|            2550|               29|               24|              45|Deluxe Furniture ...|              furniture_decor|
# |1e9e8ef04dbcff454...|           perfumaria|                 40|                       287|                 1|             225|               16|               10|              14|Aroma Eau de Parf...|                    perfumery|
# |6a2fb4dd53d2cdb88...|           perfumaria|                 39|                       346|                 2|             400|               27|                5|              20|   Pure Cologne G270|                    perfumery|
# +--------------------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+--------------------+-----------------------------+
# only showing top 20 rows

# %%
products_english_df.columns
# Out:
# ['product_id',
#  'product_category_name',
#  'product_name_length',
#  'product_description_length',
#  'product_photos_qty',
#  'product_weight_g',
#  'product_length_cm',
#  'product_height_cm',
#  'product_width_cm',
#  'product_name',
#  'product_category_name_english']

# %%
#Display data types
products_english_df.printSchema()
# Out:
# root
#  |-- product_id: string (nullable = true)
#  |-- product_category_name: string (nullable = true)
#  |-- product_name_length: integer (nullable = true)
#  |-- product_description_length: integer (nullable = true)
#  |-- product_photos_qty: integer (nullable = true)
#  |-- product_weight_g: integer (nullable = true)
#  |-- product_length_cm: integer (nullable = true)
#  |-- product_height_cm: integer (nullable = true)
#  |-- product_width_cm: integer (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- product_category_name_english: string (nullable = true)

# %%
#lower case and trim for categorical data
products_english_df = products_english_df.withColumn("product_category_name_english", lower(trim(col("product_category_name_english"))))
products_english_df = products_english_df.withColumn("product_category_name", lower(trim(col("product_category_name"))))

# %%
#check for null values
products_english_df.select([count(when(col(c).isNull(), c)).alias(c) for c in products_english_df.columns]).show()
# Out:
# +----------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+------------+-----------------------------+
# |product_id|product_category_name|product_name_length|product_description_length|product_photos_qty|product_weight_g|product_length_cm|product_height_cm|product_width_cm|product_name|product_category_name_english|
# +----------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+------------+-----------------------------+
# |         0|                  610|                610|                       610|               610|               2|                2|                2|               2|           0|                          623|
# +----------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+------------+-----------------------------+

# %%
#calculate average value for each column
avg_values = products_english_df.select(
    avg("product_weight_g").alias("avg_weight"),
    avg("product_length_cm").alias("avg_length"),
    avg("product_height_cm").alias("avg_height"),
    avg("product_width_cm").alias("avg_width")
).first()

# %%
# replace null values with the calculated avg's
product_dim_nulls_filled_df = products_english_df.fillna({
    "product_weight_g": avg_values["avg_weight"],
    "product_length_cm": avg_values["avg_length"],
    "product_height_cm": avg_values["avg_height"],
    "product_width_cm": avg_values["avg_width"]
})

# %%
# recheck for nulls
product_dim_nulls_filled_df.select([
    count(when(col(c).isNull(), c)).alias(c)
    for c in ["product_weight_g", "product_length_cm", "product_height_cm", "product_width_cm"]
]).show()
# Out:
# +----------------+-----------------+-----------------+----------------+
# |product_weight_g|product_length_cm|product_height_cm|product_width_cm|
# +----------------+-----------------+-----------------+----------------+
# |               0|                0|                0|               0|
# +----------------+-----------------+-----------------+----------------+

# %%
#double check for null values for the full dataset
product_dim_nulls_filled_df.select([count(when(col(c).isNull(), c)).alias(c) for c in product_dim_nulls_filled_df.columns]).show()
# Out:
# +----------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+------------+-----------------------------+
# |product_id|product_category_name|product_name_length|product_description_length|product_photos_qty|product_weight_g|product_length_cm|product_height_cm|product_width_cm|product_name|product_category_name_english|
# +----------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+------------+-----------------------------+
# |         0|                  610|                610|                       610|               610|               0|                0|                0|               0|           0|                          623|
# +----------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+------------+-----------------------------+

# %%
# Group by product_id , to calculate duplicates
duplicates_df = product_dim_nulls_filled_df.groupBy("product_id").count().filter(col("count") > 1)

# dislay duplicate rows
print("عدد المنتجات المكررة:")
print(duplicates_df.count())
duplicates_df.show()
# Out:
# عدد المنتجات المكررة:
# 0
# +----------+-----+
# |product_id|count|
# +----------+-----+
# +----------+-----+

# %%
#Drop duplicates
product_dim_nulls_filled_df = product_dim_nulls_filled_df.dropDuplicates(["product_id"])

# %%
# check for outliers: width , hight or length <= 0
outliers_df = product_dim_nulls_filled_df.filter(
    (col("product_weight_g") <= 0) |
    (col("product_length_cm") <= 0) |
    (col("product_height_cm") <= 0) |
    (col("product_width_cm") <= 0)
)

# display outliers rows
print("عدد الصفوف التي تحتوي على outliers:")
print(outliers_df.count())
outliers_df.show()
# Out:
# عدد الصفوف التي تحتوي على outliers:
# 4
# +--------------------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+--------------------+-----------------------------+
# |          product_id|product_category_name|product_name_length|product_description_length|product_photos_qty|product_weight_g|product_length_cm|product_height_cm|product_width_cm|        product_name|product_category_name_english|
# +--------------------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+--------------------+-----------------------------+
# |36ba42dd187055e1f...|      cama_mesa_banho|                 53|                       528|                 1|               0|               30|               25|              30|Deluxe Bed Table ...|               bed_bath_table|
# |8038040ee2a71048d...|      cama_mesa_banho|                 48|                       528|                 1|               0|               30|               25|              30|Essential Bed Tab...|               bed_bath_table|
# |81781c0fed9fe1ad6...|      cama_mesa_banho|                 51|                       529|                 1|               0|               30|               25|              30|Essential Bed Tab...|               bed_bath_table|
# |e673e90efa65a5409...|      cama_mesa_banho|                 53|                       528|                 1|               0|               30|               25|              30|Professional Bed ...|               bed_bath_table|
# +--------------------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+--------------------+-----------------------------+

# %%
# create tempveiw df
product_dim_nulls_filled_df.createOrReplaceTempView("products")

# %%
# average weight for each category
spark.sql("""
    CREATE OR REPLACE TEMP VIEW category_avg_weight AS
    SELECT product_category_name, AVG(product_weight_g) AS avg_weight
    FROM products
    WHERE product_weight_g > 0
    GROUP BY product_category_name
""")
# Out:
# DataFrame[]

# %%
# replace 0 weight values by the average value of its own category
products_trimed_outliers = spark.sql("""
    SELECT
        p.*,
        CASE
            WHEN p.product_weight_g = 0 THEN c.avg_weight
            ELSE p.product_weight_g
        END AS product_weight_g_cleaned
    FROM products p
    LEFT JOIN category_avg_weight c
    ON p.product_category_name = c.product_category_name
""")

# %%
# rename the outlier trimmed column
products_trimed_outliers = products_trimed_outliers.drop("product_weight_g") \
    .withColumnRenamed("product_weight_g_cleaned", "product_weight_g")

# %%
#remove duplicate column
products_trimed_outliers = products_trimed_outliers.withColumnRenamed("product_weight_g_cleaned", "product_weight_g")

# %%
#make sure outlires have been trimed

outliers_df = products_trimed_outliers.filter(
    (col("product_weight_g") <= 0) |
    (col("product_length_cm") <= 0) |
    (col("product_height_cm") <= 0) |
    (col("product_width_cm") <= 0)
)

# display
print("عدد الصفوف التي تحتوي على outliers:")
print(outliers_df.count())
outliers_df.show()
# Out:
# عدد الصفوف التي تحتوي على outliers:
# 0
# +----------+---------------------+-------------------+--------------------------+------------------+-----------------+-----------------+----------------+------------+-----------------------------+----------------+
# |product_id|product_category_name|product_name_length|product_description_length|product_photos_qty|product_length_cm|product_height_cm|product_width_cm|product_name|product_category_name_english|product_weight_g|
# +----------+---------------------+-------------------+--------------------------+------------------+-----------------+-----------------+----------------+------------+-----------------------------+----------------+
# +----------+---------------------+-------------------+--------------------------+------------------+-----------------+-----------------+----------------+------------+-----------------------------+----------------+

# %%
# calculate product weight: by cm^3
product_drived_col = products_trimed_outliers.withColumn(
    "product_volume_cm3",
    col("product_length_cm") * col("product_height_cm") * col("product_width_cm")
)

# %%
product_drived_col.show()
# Out:
# +--------------------+---------------------+-------------------+--------------------------+------------------+-----------------+-----------------+----------------+--------------------+-----------------------------+----------------+------------------+
# |          product_id|product_category_name|product_name_length|product_description_length|product_photos_qty|product_length_cm|product_height_cm|product_width_cm|        product_name|product_category_name_english|product_weight_g|product_volume_cm3|
# +--------------------+---------------------+-------------------+--------------------------+------------------+-----------------+-----------------+----------------+--------------------+-----------------------------+----------------+------------------+
# |00066f42aeeb9f300...|           perfumaria|                 53|                       596|                 6|               20|               16|              16|   Pure Cologne W708|                    perfumery|           300.0|              5120|
# |0011c512eb256aa0d...|           automotivo|                 58|                       177|                 1|               16|               15|              16|Essential Automot...|                         auto|           100.0|              3840|
# |00126f27c81360368...|           cool_stuff|                 42|                      2461|                 1|               25|                5|              15|Essential Cool St...|                   cool_stuff|           700.0|              1875|
# |001795ec6f1b187d3...|       consoles_games|                 53|                       274|                 1|               30|               20|              20|Premium Consoles ...|               consoles_games|           600.0|             12000|
# |001b237c0e9bb435f...|      cama_mesa_banho|                 42|                       253|                 1|               40|                4|              30|Professional Bed ...|               bed_bath_table|          6000.0|              4800|
# |001c5d71ac6ad696d...|      cama_mesa_banho|                 50|                       381|                 1|               47|               21|              41|Classic Bed Table...|               bed_bath_table|          1800.0|             40467|
# |002159fe700ed3521...|     fashion_calcados|                 55|                       344|                 3|               36|               37|              16|Professional Fash...|                fashion_shoes|          1850.0|             21312|
# |00250175f79f584c1...| utilidades_domest...|                 53|                       631|                 2|               30|                5|              35|Essential Domesti...|                   housewares|           750.0|              5250|
# |002d4ea7c04739c13...|             pet_shop|                 59|                      1295|                 1|               20|               11|              11|Deluxe Pet Shop M...|                     pet_shop|           200.0|              2420|
# |0030e635639c898b3...|   ferramentas_jardim|                 40|                       437|                 1|               26|                6|              20|Professional Gard...|                 garden_tools|          1550.0|              3120|
# |0043c62d00db47eff...|        esporte_lazer|                 36|                      1105|                 1|               18|               12|              14|PowerFlex Fitness...|               sports_leisure|           380.0|              3024|
# |004636c889c7c3dad...| utilidades_domest...|                 46|                       647|                 1|               30|               10|              25|Classic Domestic ...|                   housewares|           550.0|              7500|
# |005c6b24cc96dca3e...| fashion_roupa_mas...|                 33|                       384|                 1|               17|                7|              20|Professional Mens...|         fashion_male_clot...|           400.0|              2380|
# |006c67546bfe73c33...|           automotivo|                 59|                       703|                 6|               47|               19|              23|Essential Automot...|                         auto|          4550.0|             20539|
# |0081787b18cce4acc...| construcao_ferram...|                 56|                       841|                 1|               32|               14|              27|Deluxe Constructi...|         construction_tool...|          1340.0|             12096|
# |008686d56f4c85b98...|      cama_mesa_banho|                 44|                       216|                 1|               37|               10|              32|Deluxe Bed Table ...|               bed_bath_table|          2200.0|             11840|
# |008b51e6be49ee039...|   relogios_presentes|                 57|                       676|                 2|               19|               12|              17|Essential Watches...|                watches_gifts|           633.0|              3876|
# |00917855135d67fb0...| informatica_acess...|                 55|                       197|                 1|               16|               16|              11|Deluxe Informatic...|         computers_accesso...|          1133.0|              2816|
# |009c09f439988bc06...|           perfumaria|                 39|                       991|                 3|               20|               20|              20|Elite Fragrance Y433|                    perfumery|           150.0|              8000|
# |00ae7076313576f94...|        esporte_lazer|                 38|                       440|                 1|               22|               33|              16|PowerFlex Exercis...|               sports_leisure|           600.0|             11616|
# +--------------------+---------------------+-------------------+--------------------------+------------------+-----------------+-----------------+----------------+--------------------+-----------------------------+----------------+------------------+
# only showing top 20 rows

# %%
product_drived_col.printSchema()
# Out:
# root
#  |-- product_id: string (nullable = true)
#  |-- product_category_name: string (nullable = true)
#  |-- product_name_length: integer (nullable = true)
#  |-- product_description_length: integer (nullable = true)
#  |-- product_photos_qty: integer (nullable = true)
#  |-- product_length_cm: integer (nullable = true)
#  |-- product_height_cm: integer (nullable = true)
#  |-- product_width_cm: integer (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- product_category_name_english: string (nullable = true)
#  |-- product_weight_g: double (nullable = true)
#  |-- product_volume_cm3: integer (nullable = true)

# %%
#change derived col datatype ###
product_drived_col = product_drived_col.withColumn("product_weight_g", col("product_weight_g").cast("integer"))

# %%
product_drived_col.printSchema()
# Out:
# root
#  |-- product_id: string (nullable = true)
#  |-- product_category_name: string (nullable = true)
#  |-- product_name_length: integer (nullable = true)
#  |-- product_description_length: integer (nullable = true)
#  |-- product_photos_qty: integer (nullable = true)
#  |-- product_length_cm: integer (nullable = true)
#  |-- product_height_cm: integer (nullable = true)
#  |-- product_width_cm: integer (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- product_category_name_english: string (nullable = true)
#  |-- product_weight_g: integer (nullable = true)
#  |-- product_volume_cm3: integer (nullable = true)

# %%
#make surrogate_key starting from 1

window_spec = Window.orderBy("product_id")

# addind surrogate_key column
products_final_df = product_drived_col.withColumn(
    "surrogate_key", row_number().over(window_spec)
)

# %%
products_final_df.columns
# Out:
# ['product_id',
#  'product_category_name',
#  'product_name_length',
#  'product_description_length',
#  'product_photos_qty',
#  'product_length_cm',
#  'product_height_cm',
#  'product_width_cm',
#  'product_name',
#  'product_category_name_english',
#  'product_weight_g',
#  'product_volume_cm3',
#  'surrogate_key']

# %%
# Rearranging the columns
products_dim = products_final_df.select(
    "surrogate_key",
    "product_id",
    "product_name",
    "product_category_name_english",
    "product_category_name",
    "product_name_length",
    "product_description_length",
    "product_photos_qty",
    "product_length_cm",
    "product_height_cm",
    "product_width_cm",
    "product_weight_g",
    "product_volume_cm3"

)

# %%
products_dim.show()
# Out:
# +-------------+--------------------+--------------------+-----------------------------+---------------------+-------------------+--------------------------+------------------+-----------------+-----------------+----------------+----------------+------------------+
# |surrogate_key|          product_id|        product_name|product_category_name_english|product_category_name|product_name_length|product_description_length|product_photos_qty|product_length_cm|product_height_cm|product_width_cm|product_weight_g|product_volume_cm3|
# +-------------+--------------------+--------------------+-----------------------------+---------------------+-------------------+--------------------------+------------------+-----------------+-----------------+----------------+----------------+------------------+
# |            1|00066f42aeeb9f300...|   Pure Cologne W708|                    perfumery|           perfumaria|                 53|                       596|                 6|               20|               16|              16|             300|              5120|
# |            2|00088930e925c41fd...|Premium Automotiv...|                         auto|           automotivo|                 56|                       752|                 4|               55|               10|              26|            1225|             14300|
# |            3|0009406fd7479715e...|Classic Bed Table...|               bed_bath_table|      cama_mesa_banho|                 50|                       266|                 2|               45|               15|              35|             300|             23625|
# |            4|000b8f95fcb9e0096...|Professional Dome...|                   housewares| utilidades_domest...|                 25|                       364|                 3|               19|               24|              12|             550|              5472|
# |            5|000d9be29b5207b54...|Deluxe Watches Gi...|                watches_gifts|   relogios_presentes|                 48|                       613|                 4|               22|               11|              15|             250|              3630|
# |            6|0011c512eb256aa0d...|Essential Automot...|                         auto|           automotivo|                 58|                       177|                 1|               16|               15|              16|             100|              3840|
# |            7|00126f27c81360368...|Essential Cool St...|                   cool_stuff|           cool_stuff|                 42|                      2461|                 1|               25|                5|              15|             700|              1875|
# |            8|001795ec6f1b187d3...|Premium Consoles ...|               consoles_games|       consoles_games|                 53|                       274|                 1|               30|               20|              20|             600|             12000|
# |            9|001b237c0e9bb435f...|Professional Bed ...|               bed_bath_table|      cama_mesa_banho|                 42|                       253|                 1|               40|                4|              30|            6000|              4800|
# |           10|001b72dfd63e9833e...|Deluxe Furniture ...|              furniture_decor|     moveis_decoracao|                 45|                       520|                 3|               26|                8|              22|             600|              4576|
# |           11|001c5d71ac6ad696d...|Classic Bed Table...|               bed_bath_table|      cama_mesa_banho|                 50|                       381|                 1|               47|               21|              41|            1800|             40467|
# |           12|00210e41887c2a8ef...|Classic Beauty He...|                health_beauty|         beleza_saude|                 56|                      3893|                 6|               30|               15|              15|             300|              6750|
# |           13|002159fe700ed3521...|Professional Fash...|                fashion_shoes|     fashion_calcados|                 55|                       344|                 3|               36|               37|              16|            1850|             21312|
# |           14|0021a87d4997a48b6...|Professional Info...|         computers_accesso...| informatica_acess...|                 58|                       946|                 6|               25|               10|              15|             650|              3750|
# |           15|00250175f79f584c1...|Essential Domesti...|                   housewares| utilidades_domest...|                 53|                       631|                 2|               30|                5|              35|             750|              5250|
# |           16|002552c0663708129...|Essential Cool St...|                   cool_stuff|           cool_stuff|                 18|                       263|                 1|               22|               16|              12|             355|              4224|
# |           17|002959d7a0b0990fe...|Classic Furniture...|              furniture_decor|     moveis_decoracao|                 54|                      1750|                 3|              105|                3|              70|            2600|             22050|
# |           18|002af88741ba70c7b...|Professional Cool...|                   cool_stuff|           cool_stuff|                 44|                       629|                 3|               40|               30|              40|             600|             48000|
# |           19|002c6dab60557c48c...|Premium Toys Max ...|                         toys|           brinquedos|                 43|                       112|                 5|               45|               30|              30|             350|             40500|
# |           20|002d4ea7c04739c13...|Deluxe Pet Shop M...|                     pet_shop|             pet_shop|                 59|                      1295|                 1|               20|               11|              11|             200|              2420|
# +-------------+--------------------+--------------------+-----------------------------+---------------------+-------------------+--------------------------+------------------+-----------------+-----------------+----------------+----------------+------------------+
# only showing top 20 rows

# %% [markdown]
# ## Payment Fact

# %%
#Reding payment table from postgre
order_payment_df = spark.read \
    .format("jdbc") \
    .option("url", "jdbc:postgresql://localhost:5432/olist?ssl=false")\
    .option("dbtable", "public.order_payments") \
    .option("user", "postgres") \
    .option("password", "123") \
    .option("driver", "org.postgresql.Driver") \
    .load()

# %%
order_payment_df.show()
# Out:
# +--------------------+------------------+------------+--------------------+-------------+
# |            order_id|payment_sequential|payment_type|payment_installments|payment_value|
# +--------------------+------------------+------------+--------------------+-------------+
# |b81ef226f3fe1789b...|                 1| credit_card|                   8|        99.33|
# |a9810da82917af2d9...|                 1| credit_card|                   1|        24.39|
# |25e8ea4e93396b6fa...|                 1| credit_card|                   1|        65.71|
# |ba78997921bbcdc13...|                 1| credit_card|                   8|       107.78|
# |42fdf880ba16b47b5...|                 1| credit_card|                   2|       128.45|
# |298fcdf1f73eb413e...|                 1| credit_card|                   2|        96.12|
# |771ee386b001f0620...|                 1| credit_card|                   1|        81.16|
# |3d7239c394a212faa...|                 1| credit_card|                   3|        51.84|
# |1f78449c87a54faf9...|                 1| credit_card|                   6|       341.09|
# |0573b5e23cbd79800...|                 1|      boleto|                   1|        51.95|
# |d88e0d5fa41661ce0...|                 1| credit_card|                   8|       188.73|
# |2480f727e869fdeb3...|                 1| credit_card|                   1|        141.9|
# |616105c9352a9668c...|                 1| credit_card|                   1|        75.78|
# |cf95215a722f3ebf2...|                 1| credit_card|                   5|       102.66|
# |769214176682788a9...|                 1| credit_card|                   4|       105.28|
# |12e5cfe0e4716b59a...|                 1| credit_card|                  10|       157.45|
# |61059985a6fc0ad64...|                 1| credit_card|                   1|       132.04|
# |79da3f5fe31ad1e45...|                 1| credit_card|                   1|        98.94|
# |8ac09207f415d55ac...|                 1| credit_card|                   4|       244.15|
# |b2349a3f20dfbeef6...|                 1| credit_card|                   3|       136.71|
# +--------------------+------------------+------------+--------------------+-------------+
# only showing top 20 rows

# %%
order_payment_df.columns
# Out:
# ['order_id',
#  'payment_sequential',
#  'payment_type',
#  'payment_installments',
#  'payment_value']

# %%
#check data types
order_payment_df.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- payment_sequential: integer (nullable = true)
#  |-- payment_type: string (nullable = true)
#  |-- payment_installments: integer (nullable = true)
#  |-- payment_value: double (nullable = true)

# %%
#lower case and trim for categorical data
order_payment_df = order_payment_df.withColumn("payment_type", lower(trim(col("payment_type"))))

# %%
#check for null values
order_payment_df.select([count(when(col(c).isNull(), c)).alias(c) for c in order_payment_df.columns]).show()
# Out:
# +--------+------------------+------------+--------------------+-------------+
# |order_id|payment_sequential|payment_type|payment_installments|payment_value|
# +--------+------------------+------------+--------------------+-------------+
# |       0|                 0|           0|                   0|            0|
# +--------+------------------+------------+--------------------+-------------+

# %%
# Group by product_id و نعد التكرارات
duplicates_df = order_payment_df.groupBy("order_id","payment_sequential").count().filter(col("count") > 1)

# عرض عدد الصفوف المكررة
print("عدد المدفوعات المكررة:")
print(duplicates_df.count())
duplicates_df.show()
# Out:
# عدد المدفوعات المكررة:
# 0
# +--------+------------------+-----+
# |order_id|payment_sequential|count|
# +--------+------------------+-----+
# +--------+------------------+-----+

# %%
outliers_df = order_payment_df.filter(
    (col("payment_value") <= 0))
outliers_df.count()
# Out:
# 9

# %%
outliers_df.show()
# Out:
# +--------------------+------------------+------------+--------------------+-------------+
# |            order_id|payment_sequential|payment_type|payment_installments|payment_value|
# +--------------------+------------------+------------+--------------------+-------------+
# |8bcbe01d44d147f90...|                 4|     voucher|                   1|          0.0|
# |fa65dad1b0e818e3c...|                14|     voucher|                   1|          0.0|
# |6ccb433e00daae128...|                 4|     voucher|                   1|          0.0|
# |4637ca194b6387e2d...|                 1| not_defined|                   1|          0.0|
# |00b1cb0320190ca0d...|                 1| not_defined|                   1|          0.0|
# |45ed6e85398a87c25...|                 3|     voucher|                   1|          0.0|
# |fa65dad1b0e818e3c...|                13|     voucher|                   1|          0.0|
# |c8c528189310eaa44...|                 1| not_defined|                   1|          0.0|
# |b23878b3e8eb4d25a...|                 4|     voucher|                   1|          0.0|
# +--------------------+------------------+------------+--------------------+-------------+

# %%
# create tempveiw for payment table
order_payment_df.createOrReplaceTempView("order_payments")

# %%
# check distinct payment types
v1 = spark.sql('''
SELECT payment_type,count(payment_type)
FROM order_payments
group by payment_type
''')
v1.show()
# Out:
# +------------+-------------------+
# |payment_type|count(payment_type)|
# +------------+-------------------+
# |      boleto|              19784|
# | not_defined|                  3|
# | credit_card|              76795|
# |     voucher|               5775|
# |  debit_card|               1529|
# +------------+-------------------+

# %%
# check number of installments
v1 = spark.sql('''
SELECT payment_installments,count(payment_installments)
FROM order_payments
group by payment_installments
order by payment_installments
''')
v1.show()
# Out:
# +--------------------+---------------------------+
# |payment_installments|count(payment_installments)|
# +--------------------+---------------------------+
# |                   0|                          2|
# |                   1|                      52546|
# |                   2|                      12413|
# |                   3|                      10461|
# |                   4|                       7098|
# |                   5|                       5239|
# |                   6|                       3920|
# |                   7|                       1626|
# |                   8|                       4268|
# |                   9|                        644|
# |                  10|                       5328|
# |                  11|                         23|
# |                  12|                        133|
# |                  13|                         16|
# |                  14|                         15|
# |                  15|                         74|
# |                  16|                          5|
# |                  17|                          8|
# |                  18|                         27|
# |                  20|                         17|
# +--------------------+---------------------------+
# only showing top 20 rows

# %%
#delete undefined payments
order_payment_df = order_payment_df.filter(~(col("payment_type") == "not_defined"))

# %%
# check distinct payment types after removing not_defined
v1 = spark.sql('''
SELECT payment_type,count(payment_type)
FROM order_payments
group by payment_type
''')
v1.show()
# Out:
# +------------+-------------------+
# |payment_type|count(payment_type)|
# +------------+-------------------+
# |      boleto|              19784|
# | credit_card|              76795|
# |     voucher|               5775|
# |  debit_card|               1529|
# +------------+-------------------+

# %%
#correct zero installments to 1
order_payment_df = order_payment_df.withColumn("payment_installments", when(col("payment_installments") == 0, 1).otherwise(col("payment_installments")))

# %%
# check number of installments after removing zero installments
v1 = spark.sql('''
SELECT payment_installments,count(payment_installments)
FROM order_payments
group by payment_installments
order by payment_installments
''')
v1.show()
# Out:
# +--------------------+---------------------------+
# |payment_installments|count(payment_installments)|
# +--------------------+---------------------------+
# |                   1|                      52545|
# |                   2|                      12413|
# |                   3|                      10461|
# |                   4|                       7098|
# |                   5|                       5239|
# |                   6|                       3920|
# |                   7|                       1626|
# |                   8|                       4268|
# |                   9|                        644|
# |                  10|                       5328|
# |                  11|                         23|
# |                  12|                        133|
# |                  13|                         16|
# |                  14|                         15|
# |                  15|                         74|
# |                  16|                          5|
# |                  17|                          8|
# |                  18|                         27|
# |                  20|                         17|
# |                  21|                          3|
# +--------------------+---------------------------+
# only showing top 20 rows

# %%
# add Forgin ksys

# %%
# نستخدم Window بدون partition لأن الـ order_id + payment_sequential بيضمنوا التفرد
windowSpec = Window.orderBy("order_id", "payment_sequential")

order_payment_df = order_payment_df.withColumn("order_payment_sk", row_number().over(windowSpec))

# %%
order_payment_df.columns
# Out:
# ['order_id',
#  'payment_sequential',
#  'payment_type',
#  'payment_installments',
#  'payment_value',
#  'order_payment_sk']

# %%
# Rearranging the columns
order_payment_df = order_payment_df.select('order_payment_sk',
'order_id',
'payment_sequential',
'payment_type',
'payment_installments',
'payment_value')

# %%
order_payment_df.columns
# Out:
# ['order_payment_sk',
#  'order_id',
#  'payment_sequential',
#  'payment_type',
#  'payment_installments',
#  'payment_value']
